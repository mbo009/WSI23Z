# %% [markdown]
# # WSI LAB01 Algorytm gradientu prostego

# %% [markdown]
# ### Miłosz Cieśla 325154 <br> <br>

# %% [markdown]
# ## 1. Wykresy funkcji
# Potrzebne importy:

# %%
from measurements import plt_function
import functions

# %% [markdown]
# Wykres funkcji f:
# <span style = "font-size: 32px"> $$f(x) = \frac{1}{4}x^4$$ </span>

# %%
plt_function(functions.f)

# %% [markdown]
# Wykres gradientu funkcji f:
# <span style = "font-size: 32px"> $$\nabla f(x) = x^3$$ </span>

# %%
plt_function(functions.fGradient, True)

# %% [markdown]
# Wykres funkcji 2 zmiennych g:
# <span style = "font-size: 32px">$$g(x) = 1.5 - e^{-x_1^2 - x_2^2} - 0.5e^{-(x_1-1)^2-(x_2+2)^2}$$ </span>

# %% [markdown]
# ![g(x)](g(x).png)

# %% [markdown]
# Wykres gradientu funkcji g:
# <span style = "font-size: 32px"> $$\nabla g(x) = \begin{bmatrix} 2x_1e^{-x_1^2 - x_2^2} + (x_1 - 1)e^{-(x_1-1)^2-(x_2+2)^2}  \\
# 2x_2e^{-x_1^2 - x_2^2} + (x_2 - 1)e^{-(x_1-1)^2-(x_2+2)^2} \end{bmatrix}$$
# <br> <br> </span>

# %% [markdown]
# 1 wektor:
#
# ![1 wektor gradientu g(x)](g(x)Gradient.png)

# %% [markdown]
# <br> <br> 2 wektor:
#
# ![2 wektor gradientu g(x)](g(x)Gradient2.png)
# <br> <br>

# %% [markdown]
# <br> <br>
# ## 2. Minimum funkcji:
# Dla weryfikacji wyników algorytmu sprawdzam ze strony [Wolfram Alpha](https://www.wolframalpha.com/) wartości minimalne:
# <br>

# %% [markdown]
# <span style = "font-size: 32px">$$min(f(x)) = 0$$</span>
# Osiąga taką wartość dla x = 0
# <br> <br>

# %% [markdown]
# <span style = "font-size: 32px">$$min(g(x_1, x_2)) ≈ 0,49662 $$</span>

# %% [markdown]
# Osiąga taką wartość dla x1 ≈ -0.0033 oraz x2 ≈ -0.0033
# <br> <br> <br>

# %% [markdown]
# ## 3. Przykładowe pomiary f(x):
# Potrzebne importy:
# <br>

# %%
from measurements import stepLenDependency, plt_accuracy, plt_stepLen

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 1

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 1)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-6, zaczynając od punktu x = 1

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-6, 0.001, 1e6, 1)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 2

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 2)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 2.9

# %% [markdown]
# Przeprowadzam pomiary dla 2.9 zamiast dla 3 ponieważ dla tamtej wartości algorytm potrzebuje bardzo dużo czasu.

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 2.9)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Średnia wartość dla 10 pomiarów przy precyzji 10^-4 z losowymi x0:
# Wybieramy losowe wartości x0 od -2.9 do 2.9, ponieważ poza tym obszarem inne argumenty początkowe dla tej funkcji nie są efektywne.
# <br> <br>
# Potrzebne importy:

# %%
from measurements import randXMeasurements

# %%
measurements = randXMeasurements(functions.f, functions.fGradient, 1e-4, 0.001, 1e8, 10)

# %% [markdown]
# Wylosowane x:

# %%
print(measurements[1])
# Out:
# [1.9741469457960261, 1.6677901520315, -2.695284678183891, -1.0033258990612215, -1.30201046786292, 2.014712468334442, -1.9453278569905619, -1.2121714347526638, 1.4685449102205106, -2.5921456353148327]

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Średnia wartość dla 100 pomiarów przy precyzji 10^-4 z losowymi x0:

# %%
measurements = randXMeasurements(functions.f, functions.fGradient, 1e-4, 0.001, 1e8, 100)

# %% [markdown]
# Wylosowane x:

# %%
print(measurements[1])
# Out:
# [1.215308205318514, -0.29414690730840665, 0.08290493313715652, -2.5753203003442744, -0.1832807525787432, -1.9218093530959968, 0.8172291245806802, 1.19781314525684, -0.7199981498115986, 0.3249719473085819, -2.0441142830267554, -0.19386831592118492, 0.4090021938719688, -0.12141113152254057, 0.9584923767586648, 0.8811097346438386, -0.9304818954479754, 2.2083381704650757, -1.4605227912207193, 0.6433645717086494, -2.369231784738153, -2.6867178443394284, 2.293645657800893, 1.8911379168162576, 2.865349079734384, 2.716198038177757, -2.5058990704479704, 0.12712334217214583, 0.22698279951473532, -1.2378442522407578, -0.5812412207289137, 1.639304896693203, -1.6627013064009248, -0.12074053017460828, -2.224460500512442, 1.2844524527829875, 1.513010074969737, -1.906472901852069, 1.887503487385048, 2.570790725377696, 0.8555690155997393, -1.704343734345241, 2.352776503127823, -1.3192235690715473, -0.9502704073932058, 0.7050346599421737, -1.7242609812367062, 1.7587767224268211, 1.7232833626363244, -0.2705208670342243, -0.8666212011006995, 1.0378292906702926, -2.2853846247565053, -0.07723192137174584, -0.9261910054329003, -2.3599457140511118, -2.168251878585067, 1.7176431980158537, -1.9087374655608071, -1.0799895512616913, -1.9709989482784267, -0.46357038507923454, -2.0191287838770062, 0.9797208936589028, -0.4441460763828635, -2.7504455832289874, 0.04393190841452954, 1.327537761972915, -2.0269670426943756, 2.291466465992776, -2.2422646202520915, 1.1904532590667096, -1.8553687573527602, 2.556562130033662, -1.4188011218063359, 0.18688992938915439, -0.34822849988042925, -1.483471385769728, -0.88633439542166, -0.45257745782151293, -0.2813626082416829, -2.6419666341745276, 0.4315549199905182, 0.7164443356366501, -0.501412323618744, -1.9617022163146227, 2.6387413118075886, -2.244766471176933, 0.7060119022403057, -1.5414299064689667, 1.4155503685883422, 2.5863450275623383, 2.2825051814380326, 0.3202931579221322, 0.6611031239469316, 2.122467252231544, -2.110375348998489, -1.3040680300136498, 0.7039105670858152, -2.2806436302428597]

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)
