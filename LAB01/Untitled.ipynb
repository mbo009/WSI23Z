# %% [markdown]
# # WSI LAB01 Algorytm gradientu prostego

# %% [markdown]
# ### Miłosz Cieśla 325154 <br>

# %% [markdown]
# ## Cel eksperymentu
# - Przetestowanie działania algorytmu gradientu prostego dla różnych długości kroków(learning rate)
# - Sprawdzenie jak zadana precyzja wpływa na wyniki
# - Znalezienie najbardziej optymalnego kroku dla zadanych funkcji
# - Obserwacja wpływu punktu startowego na działanie

# %% [markdown]
# ## 1. Wykresy funkcji
# Potrzebne importy:

# %%
from measurements import plt_function
import functions

# %% [markdown]
# Wykres funkcji f:
# <span style = "font-size: 32px"> $$f(x) = \frac{1}{4}x^4$$ </span>

# %%
plt_function(functions.f)

# %% [markdown]
# Wykres gradientu funkcji f:
# <span style = "font-size: 32px"> $$\nabla f(x) = x^3$$ </span>

# %%
plt_function(functions.fGradient, True)

# %% [markdown]
# Wykres funkcji 2 zmiennych g:
# <span style = "font-size: 32px">$$g(x) = 1.5 - e^{-x_1^2 - x_2^2} - 0.5e^{-(x_1-1)^2-(x_2+2)^2}$$ </span>

# %% [markdown]
# ![g(x)](g(x).png)

# %% [markdown]
# Wykres gradientu funkcji g:
# <span style = "font-size: 32px"> $$\nabla g(x) = \begin{bmatrix} 2x_1e^{-x_1^2 - x_2^2} + (x_1 - 1)e^{-(x_1-1)^2-(x_2+2)^2}  \\
# 2x_2e^{-x_1^2 - x_2^2} + (x_2 - 1)e^{-(x_1-1)^2-(x_2+2)^2} \end{bmatrix}$$
# <br> <br> </span>

# %% [markdown]
# 1 wektor:
#
# ![1 wektor gradientu g(x)](g(x)Gradient.png)

# %% [markdown]
# <br> <br> 2 wektor:
#
# ![2 wektor gradientu g(x)](g(x)Gradient2.png)
# <br> <br>

# %% [markdown]
# <br> <br>
# ## 2. Minimum funkcji:
# Dla weryfikacji wyników algorytmu sprawdzam ze strony [Wolfram Alpha](https://www.wolframalpha.com/) wartości minimalne:
# <br>

# %% [markdown]
# <span style = "font-size: 32px">$$min(f(x)) = 0$$</span>
# Osiąga taką wartość dla x = 0
# <br> <br>

# %% [markdown]
# <span style = "font-size: 32px">$$min(g(x_1, x_2)) ≈ 0,49662 $$</span>

# %% [markdown]
# Osiąga taką wartość dla x1 ≈ -0.0033 oraz x2 ≈ -0.0033
# <br> <br> <br>

# %% [markdown]
# ## 3. Przykładowe pomiary f(x):
# Potrzebne importy:
# <br>

# %%
from measurements import stepLenDependency, plt_accuracy, plt_stepLen

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 1

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 1)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-6, zaczynając od punktu x = 1

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-6, 0.001, 1e6, 1)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 2

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 2)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 2.9

# %% [markdown]
# Przeprowadzam pomiary dla 2.9 zamiast dla 3 ponieważ dla tamtej wartości algorytm potrzebuje bardzo dużo czasu.

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 2.9)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Średnia wartość dla 10 pomiarów przy precyzji 10^-4 z losowymi x0:
# Wybieramy losowe wartości x0 od -2.9 do 2.9, ponieważ poza tym obszarem inne argumenty początkowe dla tej funkcji nie są efektywne.
# <br> <br>
# Potrzebne importy:

# %%
from measurements import randXMeasurements

# %%
measurements = randXMeasurements(functions.f, functions.fGradient, 1e-4, 0.001, 1e8, 10, [-2.9, 2.9])

# %% [markdown]
# Wylosowane x:

# %%
print(measurements[1])
# Out:
# [1.9741469457960261, 1.6677901520315, -2.695284678183891, -1.0033258990612215, -1.30201046786292, 2.014712468334442, -1.9453278569905619, -1.2121714347526638, 1.4685449102205106, -2.5921456353148327]

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Średnia wartość dla 500 pomiarów przy precyzji 10^-4 z losowymi x0:

# %%
measurements = randXMeasurements(functions.f, functions.fGradient, 1e-4, 0.001, 1e8, 1000, [-2.9, 2.9])

# %% [markdown]
# Wylosowane x:

# %%
print(measurements[1])
# Out:
# [0.0771388510114912, 0.6145581359010208, 1.5122309674953134, -0.7589942424997518, 2.70027929010652, 1.2003043805309015, -2.4431919871122822, 2.2321026537110034, -0.7272524590767655, 1.0848881333461793, 0.1604973674102359, -0.5178289370022391, -1.4935446484760697, 0.5624389312682698, -2.3195931239545597, 1.6153919973669457, -2.6025651354355412, -2.583439274994927, -1.6148367537429709, -2.6063483174347866, 2.223169926590303, -1.278279357127916, -1.016276432743702, -1.1697090003868424, -0.17882845904141664, -0.4644812165294643, -1.0999130088213245, 0.8683231581127551, -2.0784760458510045, 2.360511215582067, 2.865067732205015, 0.1876790717645611, -1.8465547799633695, 2.4180821363457805, 2.6953103479334497, 2.584386890681214, -0.5216324898488134, 2.4067466931226362, -1.654414594283564, -1.617178357633863, -2.1142557337319348, -1.8306325479638834, 2.5501165339382, -0.7878698367692545, -0.11950178717210358, 1.8801193227348612, 2.579092122703996, 2.0151607435044503, -2.856514653296978, 2.544076637860305, 0.2550623490266206, -0.19615795340689068, 2.2030348474373, 0.8857021581160054, 2.4165748169860986, 0.3166039416465858, -1.8504939002305965, 0.6057965662287037, 0.014116573957638767, 1.0326707722357344, 1.7898295382483824, -1.0153770122075363, -2.4956937764572196, 0.277902639872897, -0.00443013181940799, 0.21853182236344493, 1.8353950328939228, 2.5082678504463973, 2.251223676303988, 2.421960507656672, 1.721399220237259, 1.193911421672658, -0.06867559943671653, 1.857496735321591, 0.8269716336989337, 0.7663996799025998, -0.7975196522594223, 0.7404443922648833, -2.689225349016964, -1.0393093105763713, -1.1451829596724503, 0.9651406819487232, 0.10238923883511575, -1.1521076424108065, -0.05427327579392527, 1.7848770898061912, 1.533972098195624, 1.4152527493825366, 1.2953999118915331, 0.7026121782281032, 2.505636668737584, 1.1104163656200554, -1.14224326053185, 0.0682672055653164, 0.5589729104480128, -2.092757804224932, -2.3734258885493245, 2.476028948916847, -1.8072452377173038, 0.3587196005271358, 1.1877861755378896, 2.463702334371493, 1.5487565435343433, -0.7501015738123229, 1.7639583624448352, 0.18829322499432966, -2.6918598772836124, 1.510903031280192, 2.3583737478729234, 1.016627759632994, -0.47604961036091487, 0.7933858367566415, 0.5898116867058438, -2.7589321199516084, -0.32160107175195174, 1.7907057285027013, 2.2312853813458537, -1.1197572513546998, -2.778317024055038, 0.4243735403780762, 1.4542479531542924, -0.026988631772441263, 1.5275245904651729, -2.41813579622004, 1.5916843277407282, 2.0994592573359676, -1.1501724443512942, 1.6502044707861017, -1.8747653352568876, 0.24394648937929908, -2.400711026109038, 0.6380656929211606, 2.4289782058130736, -2.808399615843603, 1.3683884156222743, 0.2543371689136862, -1.212541738607046, -0.6265020440922933, 1.3025405726735149, 2.1582177913014484, 1.9335441942387503, -1.3149424787426378, -0.6713854737181122, 1.2537727016101239, 2.3257479151275215, -1.0662113416245949, 1.4976306913965582, -1.4600317438293349, 1.6465517100354892, -0.6368862228900878, 0.9077049373938841, -2.256965480239189, 1.6737152476965549, 1.069369674486512, 2.4253057015754007, -2.389810842288742, 2.763895308505425, 0.7641400924607473, 0.809849627543477, 2.3311634257379708, -0.7087689397347687, -1.7576452425135851, 2.1924887675974554, -1.1155172776524473, -0.13376059482277736, 2.8030125359658533, -1.2111594120190072, -1.8147876800287837, 1.688532336086514, -1.497630915024482, -2.411210582811264, 1.1385597093699498, 0.34668259282498015, 1.7731313518755498, -0.4595987858041286, 0.9128487312697944, 1.9285063213048121, 1.7469654564115413, 0.6727506975601143, -1.3687458573081992, 1.5672213589022896, 2.859754338535551, 1.0083115963573537, 0.12571717353994583, 1.4278347964929101, -1.8576680514971708, -2.024925731981635, 0.6635335459779896, -1.3978458192836662, -0.722168875800572, -1.404504157717973, 0.033189421391730534, 0.3585167950244337, -1.0615209664192444, 1.716526370953718, 1.3924914657403753, -2.815539361943528, 0.53285091569 ...

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ## 3. Przykładowe pomiary g(x):

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x1 = 1, x2 = 1

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-4, 0.001, 1e6, [1,1], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x1 = 2, x2 = 1

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-4, 0.001, 1e6, [2,1], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x1 = 1, x2 = 2

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-4, 0.001, 1e6, [2,1], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %% [markdown]
# Jak możemy zauważyc przez kształt funkcji g(x) zamiana x1 oraz x2 miejscami w większości przypadków będzie zwracała takie same wartości

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x1 = 2, x2 = 2

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-4, 0.001, 1e6, [2,2], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# Przy małych krokach dla x0 oddalonego bardziej od oczekiwanego wyniku, algorytm sobie nie radzi kończąc swoje działanie po 1-2 krokach.

# %% [markdown]
# ### Pomiary dla precyzji 10^-8, zaczynając od punktu x1 = 2, x2 = 2
# Biorąc pod uwage wyniki z poprzedniego pomiaru sprawdźmy czy zwiększenie precyzji umożliwi algorytmowi dojście do oczekiwanego wyniku.

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-8, 0.001, 1e6, [2,2], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# Możemy zauważyć, że przy większej precyzji wyeliminowaliśmy sytuacje w której ta funkcja kończy swoje działanie z zła wartości i małą ilością prób.

# %% [markdown]
# ### Pomiary dla precyzji 10^-6, zaczynając od punktu x1 = 2.5, x2 = 2.5

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-6, 0.001, 1e4, [2.5,2.5], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# Używanie punktów startowych powyżej 2 okazuje się już nieefektywne.

# %% [markdown]
# ### Pomiary dla precyzji 10^-6, zaczynając od punktu x1 = 3, x2 = 3

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-6, 0.001, 1e4, [3,3], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# Podobnie jak w funkcji f(x) widzimy, że funkcja nie radzi sobie z większymi x0, w tym przypadku powyżej x > 3. <br>
# W g(x) wynika to z bardzo bliskich zeru wartości gradientu.

# %% [markdown]
# ### Średnia wartość dla 10 pomiarów przy precyzji 10^-4 z losowymi x0:
# Wybieramy losowe wartości x1, x2 od -2 do 2, ponieważ poza tym obszarem inne argumenty początkowe dla tej funkcji nie są efektywne.
# <br> <br>

# %%
measurements = randXMeasurements(functions.g, functions.gGradient, 1e-4, 0.001, 1e8, 10, [-2,2], 2)

# %% [markdown]
# wylosowane x:

# %%
print(measurements[1])
# Out:
# [[-1.5267467892919653, -0.5919809873632742], [0.852446455200754, -1.2765022577248897], [1.2964527573892344, 1.4689129804095216], [-1.6937162398923, 0.7533713441320788], [0.49461603759583683, 0.46190829835736036], [-0.2994144526145299, 0.9805468799343591], [1.2178086615288204, 1.5888682220630561], [0.543034865887793, -0.9523513588971175], [0.05225371919136679, -1.8866113068133785], [1.4640720929836495, 0.41349571135567453]]

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Średnia wartość dla 1000 pomiarów przy precyzji 10^-4 z losowymi x0:

# %%
measurements = randXMeasurements(functions.g, functions.gGradient, 1e-4, 0.001, 1e8, 1000, [-2,2], 2)

# %% [markdown]
# wylosowane x:

# %%
print(measurements[1])
# Out:
# [[0.37771867361886535, -0.654754447731186], [-1.2286307456311323, -1.48766923281558], [0.05556530922506919, 0.5576389157738193], [1.4878192168151414, 1.5275218884104738], [-1.8277443592157714, -1.2650570247424966], [-0.7439382362494062, 1.3855864073330024], [0.49532228098881115, -0.4366761062023552], [1.8039961803678013, 0.05768026222499589], [0.992485822422164, -1.3089239642746189], [-0.5663160293773055, 1.7079246897295648], [1.0047406222726614, -0.44760204994046227], [-0.5681923838795169, 1.468893146398301], [-1.2735307653595416, -1.5071371398829494], [-0.7039770737149933, 1.392104712453977], [0.2081194834125215, 0.852252955069126], [1.590728530183291, -1.3071083985139649], [0.7068373072314897, 1.7477095099276534], [-1.7399678668584277, 0.4398678025095939], [-0.8219381057309256, -0.15512926635112878], [-1.7825801403794337, 1.7615070888673774], [0.9415250003524109, 1.6778196385715831], [-1.196946754499686, 1.2548529095759413], [-1.5179952644982202, 1.3304927950684622], [-0.5252387825119276, 1.8605952085380597], [1.5814723085890545, 1.967015334245899], [-1.5874721023078484, -0.7185194702381557], [1.5171346726524422, 1.7852936841168034], [1.9655153170296016, 0.968803751104458], [1.9479617944207215, -0.9778679862615776], [-1.3364243288438153, 0.7932467062728685], [-0.0605585617452391, 1.9296532333805145], [-1.0294702108407474, -1.8265814348672667], [1.6960400676825893, 0.08583065204685036], [-0.3135049551874318, 1.4237378511589744], [-0.43880104767813766, -1.9796893678876937], [-0.3996259843816081, -1.9853637944482134], [0.6967490080000927, -1.482343664659373], [1.3216793178472348, -1.8660275133550734], [-1.2159273143575935, 0.40449025155267426], [1.0025115927265182, -1.8041650092069768], [1.6366526805201018, -0.09001769879287735], [1.5874894713991927, 0.5540578402069447], [-0.0008963453896431162, 0.14828005260805321], [-0.5770064353926632, -1.8044376113287361], [-1.2315440672810527, 1.8403835618990878], [-0.32550083599708035, 0.30009685845329725], [-0.8809474162291315, 1.998171250393714], [0.9285229128051133, -1.2323455237478864], [0.39717391068432084, 1.475195475782245], [0.3083766499486402, 0.3922771784799637], [-0.6285721087779099, -0.6788630758758845], [0.0929923324375932, -1.9034254779579869], [0.6192094230112732, 0.2656290504168033], [0.5027965346651615, -0.499666917704809], [-1.6715188522910935, 1.2789242040390203], [0.1912970286902378, 1.2968856955923669], [1.988572927682644, 0.8519268162940761], [-1.2871728342013165, 1.4145597356656614], [-1.8697716186753306, 1.7873436577101338], [-0.8110285972846136, 0.1637402101883021], [0.42314824344099167, -1.2373726687357571], [-1.296240878808519, 0.5666800989600604], [-1.6886568370307695, 1.9248335375812768], [-0.6634027655738954, 0.2977947893356969], [-1.6351294328083017, -1.9522245532062046], [-1.4182708239189186, 1.9772376835771492], [0.06323658350087769, -0.8497473484562441], [0.33622934340247435, 1.6254380318216515], [-1.5058600155795472, -1.7097992966269318], [0.804015717240679, -1.0726183337564161], [1.6898114566332438, 1.172595178308708], [1.014444225400149, -1.1185522484513064], [-1.3270537622690823, 1.3095892107827733], [0.14485588312841458, 0.883435488082486], [-0.8238177153135804, 0.12449125541616946], [-1.6778823517734716, 0.5635698341002064], [-0.3476562679864501, 1.2880522991260857], [-0.9136995435548587, -0.4864201421026939], [-1.0359363682935383, -1.5700715160636882], [1.5502532963306739, 0.32551770310211925], [0.5919093270403821, -1.431448993752459], [1.9272494288685698, 1.2867395507990187], [-1.9437015947364227, -1.219068857643705], [-1.139373190626689, 0.038027157216927954], [-1.6456850562524115, -1.6576971775016869], [-1.4690438702381332, -1.0634502624328253], [-1.1584792649311741, 0.5626777071069511], [0.7211060772403242, 0.24412813636125064], [0.6858217790242387, 0.020606355180911695], [0.6408658049115785, 0.3080127738767473], [-1.0226242475973657, -0.4800679746720391], [-1.0315804280162113, -1.5493841330506966], [-0.09371917049490852, -1.113987818586733],  ...

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ## Znalezienie uniwersalnego kroku dla obu funkcji

# %% [markdown]
# Moim zdaniem dla f(x) tym krokiem który łączy precyzje z małą ilością wymaganych kroków dla różnych punktów startowych w efektywnym dla funkcji zakresie jest: 0.23 <br>
# Natomiast dla g(x1, x2) jest to: 0.71 <br>
# ## Działanie algorytmu przy najlepszych krokach:

# %% [markdown]
# ## Wnioski z eksperymentów:
