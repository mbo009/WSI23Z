# %% [markdown]
# # WSI LAB01 Algorytm gradientu prostego

# %% [markdown]
# ### Miłosz Cieśla 325154 <br>

# %% [markdown]
# ## Cel eksperymentu
# - Przetestowanie działania algorytmu gradientu prostego dla różnych długości kroków(learning rate)
# - Sprawdzenie jak zadana precyzja wpływa na wyniki
# - Znalezienie najbardziej optymalnego kroku dla zadanych funkcji
# - Obserwacja wpływu punktu startowego na działanie

# %% [markdown]
# ## 1. Wykresy funkcji
# Potrzebne importy:

# %%
from measurements import plt_function
import functions

# %% [markdown]
# Wykres funkcji f:
# <span style = "font-size: 32px"> $$f(x) = \frac{1}{4}x^4$$ </span>

# %%
plt_function(functions.f)

# %% [markdown]
# Wykres gradientu funkcji f:
# <span style = "font-size: 32px"> $$\nabla f(x) = x^3$$ </span>

# %%
plt_function(functions.fGradient, True)

# %% [markdown]
# Wykres funkcji 2 zmiennych g:
# <span style = "font-size: 32px">$$g(x) = 1.5 - e^{-x_1^2 - x_2^2} - 0.5e^{-(x_1-1)^2-(x_2+2)^2}$$ </span>

# %% [markdown]
# ![g(x)](g(x).png)

# %% [markdown]
# Wykres gradientu funkcji g:
# <span style = "font-size: 32px"> $$\nabla g(x) = \begin{bmatrix} 2x_1e^{-x_1^2 - x_2^2} + (x_1 - 1)e^{-(x_1-1)^2-(x_2+2)^2}  \\
# 2x_2e^{-x_1^2 - x_2^2} + (x_2 - 1)e^{-(x_1-1)^2-(x_2+2)^2} \end{bmatrix}$$
# <br> <br> </span>

# %% [markdown]
# 1 wektor:
#
# ![1 wektor gradientu g(x)](g(x)Gradient.png)

# %% [markdown]
# <br> <br> 2 wektor:
#
# ![2 wektor gradientu g(x)](g(x)Gradient2.png)
# <br> <br>

# %% [markdown]
# <br> <br>
# ## 2. Minimum funkcji:
# Dla weryfikacji wyników algorytmu sprawdzam ze strony [Wolfram Alpha](https://www.wolframalpha.com/) wartości minimalne:
# <br>

# %% [markdown]
# <span style = "font-size: 32px">$$min(f(x)) = 0$$</span>
# Osiąga taką wartość dla x = 0
# <br> <br>

# %% [markdown]
# <span style = "font-size: 32px">$$min(g(x_1, x_2)) ≈ 0,49662 $$</span>

# %% [markdown]
# Osiąga taką wartość dla x1 ≈ -0.0033 oraz x2 ≈ -0.0033
# <br> <br> <br>

# %% [markdown]
# ## 3. Przykładowe pomiary f(x):
# Potrzebne importy:
# <br>

# %%
from measurements import stepLenDependency, plt_accuracy, plt_stepLen

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 1

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 1)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-6, zaczynając od punktu x = 1

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-6, 0.001, 1e6, 1)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 2

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 2)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 2.9

# %% [markdown]
# Przeprowadzam pomiary dla 2.9 zamiast dla 3 ponieważ dla tamtej wartości algorytm potrzebuje bardzo dużo czasu.

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 2.9)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Średnia wartość dla 10 pomiarów przy precyzji 10^-4 z losowymi x0:
# Wybieramy losowe wartości x0 od -2.9 do 2.9, ponieważ poza tym obszarem inne argumenty początkowe dla tej funkcji nie są efektywne.
# <br> <br>
# Potrzebne importy:

# %%
from measurements import randXMeasurements

# %%
measurements = randXMeasurements(functions.f, functions.fGradient, 1e-4, 0.001, 1e8, 10, [-2.9, 2.9])

# %% [markdown]
# Wylosowane x:

# %%
print(measurements[1])
# Out:
# [1.239017136127949, -0.792765754144046, 0.1313060096451082, 0.3122686325858566, -1.079860045662032, -1.0391064588754761, -2.4438473964752085, 2.6267689986489526, -0.7878779841180239, -1.1296426773547978]

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Średnia wartość dla 500 pomiarów przy precyzji 10^-4 z losowymi x0:

# %%
measurements = randXMeasurements(functions.f, functions.fGradient, 1e-4, 0.001, 1e8, 1000, [-2.9, 2.9])

# %% [markdown]
# Wylosowane x:

# %%
print(measurements[1])
# Out:
# [-2.704097138284068, -0.23971411120775343, -1.3428007983892607, 1.5707155065236331, -2.500686109937705, 0.47009054464176847, -0.5870753614716344, 1.3586490334151384, 0.961890744273914, -1.3500245835672935, 2.2242138436514405, 1.1076701096357762, 0.5699662616097934, -2.6026004537854566, -1.0690907158077738, 0.08808545012336522, 0.12511548243667026, -1.1854297643043141, -1.852860777826165, -1.9245781036729754, 0.6727478898927419, -0.7513186637597662, -1.264886308638368, -2.6031965799931043, 0.5901773411104179, 1.4573667169969133, 1.2546263302335778, -0.7559712520237132, 2.188013760618199, -2.030329266929978, 0.32139221959233577, 1.2303053200285068, 0.7621120288427154, 1.2354285860481604, -0.33902330062442765, 1.320365501593384, 1.7602663112326522, -2.5745991487473803, 0.7570267971338649, -2.519799937267775, -1.365875327453117, 2.6092144041368868, 1.3630529256342254, -0.75485455737893, 0.5170714202223774, -0.508444287998643, -1.6425538758633238, 2.1047906704803983, -2.1085402174687147, -2.846544289409998, 2.5161090505481813, -1.6106185338600505, -0.7076216477800892, -1.659688377910091, -0.742161114523332, 0.6887809378341316, 2.2293493803578106, 1.7586035714708852, -1.330187821012714, 2.411310267621674, 0.09574518775764052, 1.7929239383877742, 1.1764128526764241, -1.0069443630341242, -1.0541193709494403, -2.0801298718494827, -2.475620873359348, 1.2867669832360948, 0.3469047327999131, -1.2481488996738932, -2.1645363087667437, -0.46067730053143174, 1.557325171821645, -1.3729488244516952, -2.63116363276488, -2.6689675310028282, 0.17917137238881953, 2.2891869996070997, 2.6600458929128794, -2.5749877157256806, -2.7014614325766333, -1.7053572887128954, -0.027888154493440176, 1.7773173555630835, -0.20655158994731115, -0.6329405338970235, 2.2144847646679433, -1.382032158095203, 0.22526618611543725, 0.14872690541474753, -0.9182073324609914, 2.331010383185768, -0.9617299903352514, -0.2316457965996248, 1.0150737787088415, 0.6470004595076086, 2.758657391252044, 0.006411338143380796, -0.5398879935573775, -0.8939048497549589, 1.7016237214733754, 1.8661639294492773, 2.321057435033317, 2.4248719226693987, -2.5481299306284764, -0.7155604458094889, -0.07721888479789962, -1.432567406273145, 0.9088856116185582, 1.6288598498916182, -0.9641928439451599, -1.1473873072347318, 1.2364374640930715, 2.506260442243143, 0.08423890051638638, -2.8478399325530255, -0.13923664725072227, -1.2981364291209405, 0.13591427275609602, 2.4142272892138634, -0.6840473513435503, -2.324340086085704, 2.228259083677409, -2.7961167195469434, 1.0091532333904216, 1.2390167863018005, -1.4295439278475788, -1.451221428877805, 1.547522987243282, -1.4667527708279917, 2.7846334265840054, -2.4537394679810127, -0.1888165091738765, -1.0544642140599707, 1.2682274441523789, 1.9659378412476083, 0.41113150420495703, -2.1160324428183657, 2.4373430726945826, 0.19808563872369556, -0.9978115710891664, 0.5635139407547838, 1.906556232598422, 1.4760696982363322, 2.255035006116595, -0.3313622432569274, 1.91391149534001, -2.3236202901461045, -2.240140886854162, -0.0437716823880141, 0.10312749615959804, 1.1822666656626812, 2.0483415729529244, 0.38906508198822554, -0.9864309426180242, 2.8273464421182166, 1.830220944374625, -1.8311049960085917, -0.3188098236567569, -0.328975455395744, 0.9299496733871462, 0.10332678313657384, -1.4977309868971638, -2.4089852729963246, 0.34689169181966406, 0.2675185702555609, 2.5746906448063576, 1.5618513143593309, 2.3194418161735793, -2.14593183831037, -0.06222505830647185, 0.5492498474867951, 0.053543548146356645, 2.3796405773741935, 2.2231777014372978, 1.2994822067706102, 2.874015330292315, -2.7501566632520653, -2.738591730473086, -0.9989893097169629, -1.193448644911925, 1.1202951207631622, -0.9786466393368516, -2.8906620776824847, -0.9526209745965315, 1.9254478052006676, 0.5637141759586011, -2.759246103259489, 2.154695474737116, -0.20336706983865094, 0.14678977167314233, -1.9906097941081398, 1.2608288490077526, -2.1625423084296416, 0.8826952270965296, -0.4584222357115499 ...

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ## 3. Przykładowe pomiary g(x):

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x1 = 1, x2 = 1

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-4, 0.001, 1e6, [1,1], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x1 = 2, x2 = 1

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-4, 0.001, 1e6, [2,1], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x1 = 1, x2 = 2

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-4, 0.001, 1e6, [2,1], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %% [markdown]
# Jak możemy zauważyc przez kształt funkcji g(x) zamiana x1 oraz x2 miejscami w większości przypadków będzie zwracała takie same wartości

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x1 = 2, x2 = 2

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-4, 0.001, 1e6, [2,2], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# Przy małych krokach dla x0 oddalonego bardziej od oczekiwanego wyniku, algorytm sobie nie radzi kończąc swoje działanie po 1-2 krokach.

# %% [markdown]
# ### Pomiary dla precyzji 10^-8, zaczynając od punktu x1 = 2, x2 = 2
# Biorąc pod uwage wyniki z poprzedniego pomiaru sprawdźmy czy zwiększenie precyzji umożliwi algorytmowi dojście do oczekiwanego wyniku.

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-8, 0.001, 1e6, [2,2], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# Możemy zauważyć, że przy większej precyzji wyeliminowaliśmy sytuacje w której ta funkcja kończy swoje działanie z zła wartości i małą ilością prób.

# %% [markdown]
# ### Pomiary dla precyzji 10^-6, zaczynając od punktu x1 = 2.5, x2 = 2.5

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-6, 0.001, 1e4, [2.5,2.5], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# Używanie punktów startowych powyżej 2 okazuje się już nieefektywne.

# %% [markdown]
# ### Pomiary dla precyzji 10^-6, zaczynając od punktu x1 = 3, x2 = 3

# %%
measurements = stepLenDependency(functions.g, functions.gGradient, 1e-6, 0.001, 1e4, [3,3], True)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, [-0.0033,-0.0033], "Dokładność wyników", 0.001, True)

# %% [markdown]
# Podobnie jak w funkcji f(x) widzimy, że funkcja nie radzi sobie z większymi x0, w tym przypadku powyżej x > 3. <br>
# W g(x) wynika to z bardzo bliskich zeru wartości gradientu.

# %% [markdown]
# ### Średnia wartość dla 10 pomiarów przy precyzji 10^-4 z losowymi x0:
# Wybieramy losowe wartości x1, x2 od -2 do 2, ponieważ poza tym obszarem inne argumenty początkowe dla tej funkcji nie są efektywne.
# <br> <br>

# %%
measurements = randXMeasurements(functions.g, functions.gGradient, 1e-4, 0.001, 1e8, 10, [-2,2], 2)

# %% [markdown]
# wylosowane x:

# %%
print(measurements[1])
# Out:
# [[-1.2559278224540278, -1.65248607444321], [1.5184177974549073, -0.8974429281147089], [0.3302021223168863, 0.8175181196657322], [-0.3824275526799932, 0.06644027814839948], [0.2206928616924415, -1.007335262604335], [1.3591552482118288, -0.0021037465797184574], [-0.751892291794785, 0.4699176413119832], [1.370869978389118, -0.24583623447989922], [1.561221686942961, 0.7289539713849655], [1.2967561796305191, -1.4446958945566313]]

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Średnia wartość dla 1000 pomiarów przy precyzji 10^-4 z losowymi x0:

# %%
measurements = randXMeasurements(functions.g, functions.gGradient, 1e-4, 0.001, 1e8, 1000, [-2,2], 2)

# %% [markdown]
# wylosowane x:

# %%
print(measurements[1])
# Out:
# [[1.7373119969185882, 1.3676824826519534], [-0.925403944307496, -1.2905370878468787], [0.01243253419321988, -1.7988711026245752], [-1.8388052276520956, 1.681482313278456], [-0.21353434138281768, -1.0685663135276027], [1.143798130078308, -0.9928922167850582], [0.5879313312971823, -1.4355126808499516], [-1.900348872184396, 0.4539563945195022], [-0.6868501635239319, -0.06165261439581071], [1.9638400548798716, 1.9665316368028698], [0.5716607699039358, 1.3664406394563935], [1.7904599446298528, -0.9592903288979122], [-0.9741196569851267, -1.902041050962016], [-0.2668856874855412, -1.3180976402965006], [-0.28198916377051164, -0.4418354455217819], [-1.0918169325146008, 1.8370211459417298], [1.7421886440636434, 0.17992436316222715], [-0.20217191055473194, -0.9068978009891029], [0.03601020977115876, 1.9128476503440082], [-0.4660108222209578, -1.250165305822232], [1.1568493202118084, -1.738364634654975], [-0.425576964781337, 1.9259166044204945], [-1.4200268991836973, -1.1124457805902477], [1.191365063803027, 1.7844641322495156], [-0.16592190841521237, 1.4045534557604755], [-0.32316748084139757, 1.5036503395796479], [-1.3058241717733576, -1.7466052933229679], [1.4870375203829314, 1.4070941484361037], [-0.9041657451715568, -1.2950022984232832], [-0.8339946750703628, -0.6320898561945296], [-1.8460795965131092, -1.1205328009194422], [-1.1071370786996177, 0.4633551592587519], [1.8679622378241545, -1.7578025612371184], [-0.22654469006556166, 1.3772771226779055], [-0.20527735747224307, 0.8398838144590846], [-0.35866912965079045, 0.885811103146072], [-0.5867767116180089, 1.1885303920918253], [-1.0110645313466051, 1.748559984462259], [0.5703104395754037, 1.6973602973542001], [1.0565064071269696, -0.8838184993495095], [0.49110883135301275, -0.6295275815647168], [-1.800512899489911, -1.3750790905054995], [0.9901041676098026, -1.098908463431191], [1.350591174513005, 0.07616226880549126], [0.8223975740221707, 0.806030693508712], [-0.09653299952692418, -1.465818849212301], [-1.727179316623468, 1.7325204694169138], [-0.10482838498316083, -0.16976108403405554], [-0.009770724591753766, -0.6118882455615564], [-0.11757683416280251, 0.4864551572449938], [1.8745118766354034, -1.4182613951681495], [-1.0473263243627073, 1.8542186965839762], [0.803839253121112, 1.880194077211355], [-1.8857447625873864, -0.01696070177451503], [1.0594946049620733, -1.5500900828946973], [0.22290416761294285, -1.196801796043208], [-0.5368324543152361, 0.47521548576420525], [0.03410612772846955, 1.5768180676752008], [-1.1785918320206963, -0.1506746574552036], [-1.473324504337616, -0.6536546605508007], [-1.7791118472379668, -1.7107660864897238], [-1.4978131355848339, -1.5748814336582626], [0.05277293720635878, 0.5788071342884744], [-1.0375290846749428, -0.3167010118581355], [-0.3568772578320134, -0.3256230785122125], [0.16189084278087051, 0.852997486634155], [-1.2347934672357423, 1.1668323126139106], [0.02279902022071889, 0.3274387018587501], [1.0726452869017615, 0.1586992899794213], [-1.1897076032100733, -0.6096528718333301], [1.1098673459932829, 1.4395541231426163], [0.5593637122425457, 1.1749138837732351], [-0.5792593698810746, -0.23807645798137766], [0.2421607723194974, -1.1095601125207746], [1.2862951961341098, 0.3817381933460351], [-0.31234015799031933, -1.7294844402580796], [-1.8012139041959672, -1.8813017287159455], [-1.2831115535928768, 0.78187799580212], [-0.5779085824506458, -0.9198604212111237], [-1.075538978236327, -1.1405854632643049], [-1.8950339517780166, 1.4279975324328316], [-1.404667889628188, 1.8388905065241592], [0.892007095726266, 1.0494944043289083], [-1.5786758237362326, -0.011392350464302758], [1.8131254940661647, 1.1023307990153395], [1.0179427398314957, -1.7548719041801695], [-1.717253290273129, -1.0176812307199508], [-0.29230109391064296, -0.5771555483736286], [0.10499389232133449, 0.8977064221757809], [-1.4080146349443843, 1.1026237159760814], [0.7227757315937242, -1.8115130499512087], [1.4352845504248135, 1.309899888659256], [-0.5570177535129459, -1.6551 ...

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ## Znalezienie uniwersalnego kroku dla obu funkcji

# %% [markdown]
# Moim zdaniem dla f(x) tym krokiem który łączy precyzje z małą ilością wymaganych kroków dla różnych punktów startowych w efektywnym dla funkcji zakresie jest: 0.23 <br>
# Natomiast dla g(x1, x2) jest to: 0.71 <br>
# ## Działanie algorytmu przy najlepszych krokach:

# %% [markdown]
# ## Wnioski z eksperymentów:
