# %% [markdown]
# # WSI LAB01 Algorytm gradientu prostego

# %% [markdown]
# ### Miłosz Cieśla 325154 <br> <br>

# %% [markdown]
# ## 1. Wykresy funkcji
# Potrzebne importy:

# %%
from measurements import plt_function
import functions

# %% [markdown]
# Wykres funkcji f:
# <span style = "font-size: 32px"> $$f(x) = \frac{1}{4}x^4$$ </span>

# %%
plt_function(functions.f)

# %% [markdown]
# Wykres gradientu funkcji f:
# <span style = "font-size: 32px"> $$\nabla f(x) = x^3$$ </span>

# %%
plt_function(functions.fGradient, True)

# %% [markdown]
# Wykres funkcji 2 zmiennych g:
# <span style = "font-size: 32px">$$g(x) = 1.5 - e^{-x_1^2 - x_2^2} - 0.5e^{-(x_1-1)^2-(x_2+2)^2}$$ </span>

# %% [markdown]
# ![g(x)](g(x).png)

# %% [markdown]
# Wykres gradientu funkcji g:
# <span style = "font-size: 32px"> $$\nabla g(x) = \begin{bmatrix} 2x_1e^{-x_1^2 - x_2^2} + (x_1 - 1)e^{-(x_1-1)^2-(x_2+2)^2}  \\
# 2x_2e^{-x_1^2 - x_2^2} + (x_2 - 1)e^{-(x_1-1)^2-(x_2+2)^2} \end{bmatrix}$$
# <br> <br> </span>

# %% [markdown]
# 1 wektor:
#
# ![1 wektor gradientu g(x)](g(x)Gradient.png)

# %% [markdown]
# <br> <br> 2 wektor:
#
# ![2 wektor gradientu g(x)](g(x)Gradient2.png)
# <br> <br>

# %% [markdown]
# <br> <br>
# ## 2. Minimum funkcji:
# Dla weryfikacji wyników algorytmu sprawdzam ze strony [Wolfram Alpha](https://www.wolframalpha.com/) wartości minimalne:
# <br>

# %% [markdown]
# <span style = "font-size: 32px">$$min(f(x)) = 0$$</span>
# Osiąga taką wartość dla x = 0
# <br> <br>

# %% [markdown]
# <span style = "font-size: 32px">$$min(g(x_1, x_2)) ≈ 0,49662 $$</span>

# %% [markdown]
# Osiąga taką wartość dla x1 ≈ -0.0033 oraz x2 ≈ -0.0033
# <br> <br> <br>

# %% [markdown]
# ## 3. Przykładowe pomiary f(x):
# Potrzebne importy:
# <br>

# %%
from measurements import stepLenDependency, plt_accuracy, plt_stepLen

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 1

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 1)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-6, zaczynając od punktu x = 1

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-6, 0.001, 1e6, 1)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 2

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 2)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Pomiary dla precyzji 10^-4, zaczynając od punktu x = 2.9

# %% [markdown]
# Przeprowadzam pomiary dla 2.9 zamiast dla 3 ponieważ dla tamtej wartości algorytm potrzebuje bardzo dużo czasu.

# %%
measurements = stepLenDependency(functions.f, functions.fGradient, 1e-4, 0.001, 1e6, 2.9)
plt_stepLen(measurements, "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements, 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Średnia wartość dla 10 pomiarów przy precyzji 10^-4 z losowymi x0:
# Wybieramy losowe wartości x0 od -2.9 do 2.9, ponieważ poza tym obszarem inne argumenty początkowe dla tej funkcji nie są efektywne.
# <br> <br>
# Potrzebne importy:

# %%
from measurements import randXMeasurements

# %%
measurements = randXMeasurements(functions.f, functions.fGradient, 1e-4, 0.001, 1e8, 10)
# Out:
# [1.76927435960951, -1.746453711541327, -1.633562946889652, 0.601380095999327, -2.6697542527140703, -1.6247419469149391, -2.5457059039158443, 2.6895222169184865, -0.05377829214221386, 2.2457478827357797]

# %% [markdown]
# Wylosowane x:

# %%
print(measurements[1])

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)

# %% [markdown]
# ### Średnia wartość dla 100 pomiarów przy precyzji 10^-4 z losowymi x0:

# %%
measurements = randXMeasurements(functions.f, functions.fGradient, 1e-4, 0.001, 1e8, 100)
# Out:
# [-2.814670098266855, -2.6161537192991515, -0.7150362636877379, 2.847863984637359, -2.5543450630677786, 2.5318520407425633, 2.8589494276928673, -1.5401591523408502, 1.4367732630823933, -1.122121622627967, -2.5607654137808793, 1.6971607468294363, 0.0461266255309436, 0.4603848010379883, 1.0593021937715257, -2.8051640232340382, -2.045160053540437, 2.3829441840496712, 1.245528909429296, -2.3850649427164563, -0.35739790255825454, 1.909421388194326, 2.2080234205285723, 1.0453341451193738, -0.6029585174484029, -0.105226534823597, 1.539409354112014, 2.104714018948299, 0.41033482752342954, 0.7610194748637413, -2.4751799250110302, -1.7682152457635762, 2.8233279300550627, -0.42969687394230194, 1.366589669970455, -1.2206376799541854, 0.0501876354275943, -0.39809797941957337, -0.18985838651431575, -0.2883586264381197, 1.1958131725194243, -2.8758769562844906, 2.5747176644704015, 0.05308398742237852, -2.6826703047419853, -0.10466580017776872, 1.7820098749263233, 2.6564351132679858, 1.3587461447038423, 1.104634419542411, -2.7027366856860024, 2.226207248182544, 2.331070639775066, 1.5240056265051218, 2.6451811136154952, -0.3466794682973888, -2.3497040023924676, -1.75655912230845, 1.705189810546917, 0.19994198842547206, 2.4095336229933957, -0.9427102936289553, 0.8730998906813352, 2.6826436339177513, -1.636561477818224, -0.9111668011182474, -0.785152472984969, -0.3113371256920763, 2.207559874801157, 0.4434919921766123, -2.02782294229511, 1.905237556409705, 1.4954076615003928, -1.2378390943638637, -0.09077319613408275, 2.697979632887184, 2.771012588573018, -0.2691269837476664, 2.830310316657791, -2.2797553698244757, -2.855203385594655, 2.151644477792845, 0.7329423514713134, -1.3988275827634902, 0.1909917440249238, -1.9202324863799096, -2.238240288501796, -1.8762554512576892, -2.8967488129484997, 1.9512905855467015, 1.1128381392221791, 2.5210949564274565, -0.49826815282246173, 2.6412009362823814, -1.5074177642583704, -1.2367767491260424, -0.591736415318215, 0.05817528829888241, -2.211671757529425, 1.31224452495838]

# %% [markdown]
# Wylosowane x:

# %%
print(measurements[1])

# %%
plt_stepLen(measurements[0], "Liczba wymaganych kroków do długości", 0.001)

# %%
plt_accuracy(measurements[0], 0, "Dokładność wyników", 0.001)
