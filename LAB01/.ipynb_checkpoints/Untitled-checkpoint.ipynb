# %% [markdown]
# # WSI LAB01 Algorytm gradientu prostego

# %% [markdown]
# ### Miłosz Cieśla 325154 <br> <br>

# %% [markdown]
# ### 1. Wykresy funkcji
# Wykres f(x)

# %%
from measurements import plt_function
import functions

# %%
plt_function(functions.f)

# %% [markdown]
# Wykres gradientu f(x):

# %%
plt_function(functions.fGradient, True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt_function(functions.fGradient, True)
#
# TypeError: plt_function() takes 1 positional argument but 2 were given
